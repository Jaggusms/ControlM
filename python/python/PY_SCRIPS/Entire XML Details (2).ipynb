# %%
m=input("enter the name of xml file:")+'.xml'
output=m.split(".")[0]+"_details"+'.xlsx'
import xml.etree.ElementTree as et
parsexml=et.parse(m)

root=parsexml.getroot()
def VARIABLE1(VARIABLE,keypoint):
    L_VARIABLE=[]
    if VARIABLE:
        if 'VARIABLE' not in keypoint:
            keypoint.append('VARIABLE')
        
        for B in VARIABLE:
            s=list(B.attrib.values())
            L_VARIABLE.append(" ".join(s))   
        return L_VARIABLE
    else:
        if 'VARIABLE' not in keypoint:
            keypoint.append('VARIABLE')
        return ''
def RBC1(RBC,keypoint):
    L_RBC=[]
    if RBC:
        if 'RBC' not in keypoint:
            keypoint.append('RBC')

        for a in RBC:
            s=list(a.attrib.values())
            L_RBC.append(" ".join(s))
        return L_RBC
    else:
        if 'RBC' not in keypoint:
            keypoint.append('RBC')
        return ''
def CONTROL1(CONTROL,keypoint):
    L_CONTROL=[]
    if CONTROL:
        if 'CONTROL' not in keypoint:
            keypoint.append('CONTROL')

        for a in CONTROL:
            s=list(a.attrib.values())
            L_CONTROL.append(str(s[0])+' '+str(s[1]))
        return L_CONTROL
    else:
        if 'CONTROL' not in keypoint:
            keypoint.append('CONTROL')
        return '' 

def QUANTITATIVE1(QUA,keypoint):
    L_QUA=[]
    if QUA:
        if 'QUANTITATIVE' not in keypoint:
            keypoint.append('QUANTITATIVE')
        for a in QUA:
            s=list(a.attrib.values())
            L_QUA.append(str(s[0])+' '+str(s[1]))
        return L_QUA
    else:
        if 'QUANTITATIVE' not in keypoint:
            keypoint.append('QUANTITATIVE')
        return ''
    
def INCOND1(INCOND,keypoint):
    L_INCOND=[]
    if INCOND:
        if 'INCOND' not in keypoint:
            keypoint.append('INCOND')

        for a in INCOND:
            s=list(a.attrib.values())
            L_INCOND.append(str(s[0])+' '+str(s[1])+" "+str(s[2]))
        return L_INCOND	
    else:
        if 'INCOND' not in keypoint:
            keypoint.append('INCOND')
        return '' 

def OUTCOND1(OUTCOND,keypoint):
    L_OUT=[]
    if OUTCOND:
        if 'OUTCOND' not in keypoint:
            keypoint.append('OUTCOND')
        for a in OUTCOND:
            s=list(a.attrib.values())
            L_OUT.append(str(s[0])+' '+str(s[1])+" "+str(s[2]))
        return L_OUT
    else:
        if 'OUTCOND' not in keypoint:
            keypoint.append('OUTCOND')
        return ''

def ON1(ON,keypoint):
    L_ON=[]
    if ON:
        if 'ON' not in keypoint:
            keypoint.append('ON')
        key=['CODE']
        st=''
        for p in ON:
            k=list(p.attrib.keys())
            v=list(p.attrib.values())
            for q in key:
                if q in k:
                    st +=str(v[k.index(q)])+" "
                DOACTION=p.findall('DOACTION')
                if DOACTION:
                    for aB in DOACTION:
                        l=list(aB.attrib.values())
                        st +=" ".join(l)+" "
                DOCOND=p.findall('DOCOND')
                if DOCOND:
                    for aB in DOCOND:
                        l=list(aB.attrib.values())
                        st +=" ".join(l)+" "
                DOEMAIL=p.findall('DOMAIL')
                if DOEMAIL:
                    for aB in DOEMAIL:
                        l=list(aB.attrib.values())
                        st +=" ".join(l)+" "  
                DOSHOUT=p.findall('DOSHOUT')
                if DOSHOUT:
                    for aB in DOSHOUT:
                        l=list(aB.attrib.values())
                        st +=" ".join(l)+" "  
        L_ON.append(st)
        return L_ON           
    else:
        if 'ON' not in keypoint:
            keypoint.append('ON')
        return ''
def SHOUT1(SHOUT,keypoint):
    L_SHOUT=[]
    if SHOUT:
        if 'NOTFY BEFOR(0)/AFTER' not in keypoint:
            keypoint.append('NOTFY BEFOR(0)/AFTER')
        for a in SHOUT:
            s=list(a.attrib.values())
            L_SHOUT.append(" ".join(s))
        return L_SHOUT
    else:
        if 'NOTFY BEFOR(0)/AFTER' not in keypoint:
            keypoint.append('NOTFY BEFOR(0)/AFTER')
        return ''
    
keypoint=['PARENT_FOLDER','JOBNAME','DATACENTER','FOLDER_ORDER_METHOD','RUN_AS','APPLICATION','SUB_APPLICATION','DESCRIPTION','SITE_STANDARD_NAME','TIMEFROM','TIMETO','CYCLIC','INTERVAL','MAXWAIT','MAXRERUN','CONFIRM']
  
vaa=[[ 'PARENT_FOLDER','FOLDER_NAME','DATACENTER',   'FOLDER_ORDER_METHOD', 'RUN_AS', 'APPLICATION', 'SUB_APPLICATION','DESCRIPTION', 'SITE_STANDARD_NAME', 'TIMEFROM', 'TIMETO', 'CYCLIC', 'INTERVAL', 'MAXWAIT', 'MAXRERUN', 'VARIABLE', 'RBC', 'CONTROL', 'INCOND', 'OUTCOND', 'ON', 'NOTFY_BEFOR(0)/AFTER(1)']]   
vaa2=vaa    
for r in root:
    k=list(r.attrib.keys())
    v=list(r.attrib.values())

    va=[]
    for q in keypoint[:15]:
        if q in k:
            va.append(v[k.index(q)])
        else:
            if q=='FOLDER_ORDER_METHOD':
                va.append('None Manuval Order')
            else:
                va.append('')
    VARIABLE=r.findall('VARIABLE')
    va.append(VARIABLE1(VARIABLE,keypoint)) 
    
    RBC=r.findall('RULE_BASED_CALENDAR')
    va.append(RBC1(RBC,keypoint))
    
    CONTROL=r.findall('CONTROL')
    va.append(CONTROL1(CONTROL,keypoint))
    
    INCOND=r.findall('INCOND')
    va.append(INCOND1(INCOND,keypoint))
    
    OUTCOND=r.findall('OUTCOND')
    va.append(OUTCOND1(OUTCOND,keypoint))
    
    ON=r.findall('ON')
    va.append(ON1(ON,keypoint))
    
    SHOUT=r.findall('SHOUT')
    va.append(SHOUT1(SHOUT,keypoint))
    
    if va not in vaa:
        vaa.append(va)
    
for r1 in root:
    subfolder=r1.findall("SUB_FOLDER")
    for r in subfolder:
        k=list(r.attrib.keys())
        v=list(r.attrib.values())
        va=[]
        for q in keypoint[:15]:
            if q in k:
                va.append(v[k.index(q)])
            else:
                if q=='FOLDER_ORDER_METHOD':
                    va.append('None Manuval Order')
                else:
                    va.append('')
        vaa.append(va)
        VARIABLE=r.findall('VARIABLE')
        va.append(VARIABLE1(VARIABLE,keypoint)) 
    
        RBC=r.findall('RULE_BASED_CALENDAR')
        va.append(RBC1(RBC,keypoint))
    
        CONTROL=r.findall('CONTROL')
        va.append(CONTROL1(CONTROL,keypoint))
    
        INCOND=r.findall('INCOND')
        va.append(INCOND1(INCOND,keypoint))
    
        OUTCOND=r.findall('OUTCOND')
        va.append(OUTCOND1(OUTCOND,keypoint))
    
        ON=r.findall('ON')
        va.append(ON1(ON,keypoint))
    
        SHOUT=r.findall('SHOUT')
        va.append(SHOUT1(SHOUT,keypoint))
    
        if va not in vaa:
            vaa.append(va)

            
            

keypoint1=['JOBNAME','PARENT_FOLDER','APPL_TYPE','DESCRIPTION','TASKTYPE','CMDLINE','NODEID','RUN_AS','APPLICATION','SUB_APPLICATION','PRIORITY','CONFIRM','RETRO','DAYS','TIMEFROM','TIMETO','CYCLIC','MAXRERUN','INTERVAL','MAXWAIT']
vaa1=[['JOBNAME', 'PARENT_FOLDER', 'APPL_TYPE', 'DESCRIPTION', 'TASKTYPE', 'CMDLINE', 'NODEID', 'RUN_AS', 'APPLICATION', 'SUB_APPLICATION', 'PRIORITY', 'CONFIRM', 'RETRO', 'DAYS', 'TIMEFROM', 'TIMETO', 'CYCLIC', 'MAXRERUN', 'INTERVAL', 'MAXWAIT', 'VARIABLE', 'RBC', 'CONTROL', 'QUANTITATIVE', 'INCOND', 'OUTCOND', 'ON', 'NOTFY_BEFOR(0)/AFTER']]# data of the headers
vaa3=vaa1

for r in root.findall("./SMART_FOLDER/"):
    JOB=r.findall('JOB')
    #finding the all attribuets of job
    for j in JOB:
        k=list(j.attrib.keys())       
        v=list(j.attrib.values())
        va=[]
        for q in keypoint1[:20]:  #30 is length of header as for the first
            if q in k:
                va.append(v[k.index(q)])
            else:
                va.append('')
        VARIABLE=j.findall('VARIABLE')
        va.append(VARIABLE1(VARIABLE,keypoint1)) 
            
        RBC=j.findall('RULE_BASED_CALENDARS')
        va.append(RBC1(RBC,keypoint1))
    
        CONTROL=j.findall('CONTROL')
        va.append(CONTROL1(CONTROL,keypoint1))
        
        QUA=j.findall('QUANTITATIVE')
        va.append(QUANTITATIVE1(QUA,keypoint1))
            
        INCOND=j.findall('INCOND')
        va.append(INCOND1(INCOND,keypoint1))
            
        OUTCOND=j.findall('OUTCOND')
        va.append(OUTCOND1(OUTCOND,keypoint1))
            
        ON=j.findall('ON')
        va.append(ON1(ON,keypoint1))
            
        SHOUT=j.findall('SHOUT')
        va.append(SHOUT1(SHOUT,keypoint1))
        if va not in vaa:
            vaa1.append(va)



for r in root:
    JOB=r.findall('JOB')
    #finding the all attribuets of job
    for j in JOB:
        k=list(j.attrib.keys())       
        v=list(j.attrib.values())
    
        va=[]
        for q in keypoint1[:20]:  #30 is length of header as for the first
            if q in k:
                va.append(v[k.index(q)])
            else:
                va.append('')
      # variable keyword details appending in the data
        VARIABLE=j.findall('VARIABLE')
        va.append(VARIABLE1(VARIABLE,keypoint1)) 
            
        RBC=j.findall('RULE_BASED_CALENDARS')
        va.append(RBC1(RBC,keypoint1))
    
        CONTROL=j.findall('CONTROL')
        va.append(CONTROL1(CONTROL,keypoint1))
        
        QUA=j.findall('QUANTITATIVE')
        va.append(QUANTITATIVE1(QUA,keypoint1))
            
        INCOND=j.findall('INCOND')
        va.append(INCOND1(INCOND,keypoint1))
            
        OUTCOND=j.findall('OUTCOND')
        va.append(OUTCOND1(OUTCOND,keypoint1))
            
        ON=j.findall('ON')
        va.append(ON1(ON,keypoint1))
            
        SHOUT=j.findall('SHOUT')
        va.append(SHOUT1(SHOUT,keypoint1))
        if va not in vaa:
            vaa1.append(va)


            
data=vaa2
import pandas as pd
df1 = pd.DataFrame(columns=vaa2[0], data=data[1:])
df2 = pd.DataFrame(columns=vaa3[0], data=vaa3[1:])
df1['RBC']=["\n".join(i) for i in df1['RBC']]
df1['INCOND']=["\n".join(i) for i in df1['INCOND']]
df1['OUTCOND']=["\n".join(i) for i in df1['OUTCOND']]
df1['ON']=["\n".join(i) for i in df1['ON']]
df1['NOTFY_BEFOR(0)/AFTER(1)']=["\n".join(i) for i in df1['NOTFY_BEFOR(0)/AFTER(1)']]
df2['INCOND']=["\n".join(i) for i in df2['INCOND']]
df2['OUTCOND']=["\n".join(i) for i in df2['OUTCOND']]
df2['ON']=["\n".join(i) for i in df2['ON']]
df2['NOTFY_BEFOR(0)/AFTER']=["\n".join(i) for i in df2['NOTFY_BEFOR(0)/AFTER']]
with pd.ExcelWriter(output) as writer:
    df1.to_excel(writer, sheet_name='FOLDER',index=False)
    df2.to_excel(writer, sheet_name='JOB',index=False)
print("success")
# Out:
# enter the name of xml file:ir
# success

# %%
l=list(df1.FOLDER_NAME)
import os
if os.path.exists('list.txt'):
    os.remove('list.txt')
with open('list.txt', 'w') as fp:
    for item in l:
        fp.write("%s\n" % item)
cmd="{0} {1} {2} {3} {4}".format('REPORT_CODE.vbs',m,'list.txt',str(m.split(".")[0].upper())+"_CTMREPORT.txt",'miss.txt')
import subprocess
p=subprocess.run(cmd.split(),shell=True)
if p.returncode==0:
    print('success')
else:
    print("Report not generated")
# Out:
# success

# %%
import subprocess
out=subprocess.run(['dir'],shell=True,capture_output=True)
#o=subprocess.run(["ls","-a","/"], stdout=subprocess.PIPE,stderr=subprocess.STDOUT)
for i in out.stdout.decode("utf-8").split("\n"):
    print(i)
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 52F6-1F42
#
#  Directory of C:\Users\AH34976\OneDrive - Anthem\Documents\CTM\eds_deplyment
#
# 09/19/2022  10:54 AM    <DIR>          .
# 09/19/2022  10:54 AM    <DIR>          ..
# 08/26/2022  02:42 PM    <DIR>          .ipynb_checkpoints
# 09/16/2022  05:26 PM             7,470 changes.xlsx
# 09/16/2022  05:26 PM            26,112 color code on entire new old xml_.ipynb
# 08/16/2022  07:27 AM            23,120 color code on the Required folder on OLD new xml.ipynb
# 09/19/2022  10:54 AM            18,593 Entire XML Details.ipynb
# 09/16/2022  03:39 PM                31 hello.sh
# 09/19/2022  10:53 AM                42 list.txt
# 09/19/2022  08:05 AM                 0 miss.txt
# 09/16/2022  05:25 PM            13,756 POST.xml
# 09/16/2022  05:44 PM            15,568 POST_CTMREPORT.txt
# 09/19/2022  08:01 AM             7,038 pre.xlsx
# 09/16/2022  03:12 PM             4,016 pre.xml
# 09/19/2022  10:53 AM             4,665 PRE_CTMREPORT.txt
# 07/27/2021  01:35 PM             9,187 REPORT_CODE.vbs
#               13 File(s)        129,598 bytes
#                3 Dir(s)  339,691,163,648 bytes free

# %%
# Out:
# Windows IP Configuration
#
#
# Ethernet adapter Ethernet:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 1:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 2:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Wi-Fi:
#
#    Connection-specific DNS Suffix  . :
#    Link-local IPv6 Address . . . . . : fe80::f4a4:1fa2:3ef5:17bb%15
#    IPv4 Address. . . . . . . . . . . : 192.168.0.166
#    Subnet Mask . . . . . . . . . . . : 255.255.255.0
#    Default Gateway . . . . . . . . . : fe80::360a:33ff:fef1:80aa%15
#                                        192.168.0.1
#
# Ethernet adapter Bluetooth Network Connection:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :

# %%
import pandas as pd
d=pd.read_csv("command.csv")
d=d.fillna("NA_")
l=[]
for i in list(d.COMMAND):
    if "NA_" in i:
        continue
    l.append(i)
a=d[['WRAPER_SCRIPT','LIST_FILE_NAME','PATH']]
for i in a.values.tolist():
    if "NA_" in i:
        continue
    cmd="/usr/bin/ksh {0} {2}/{1}".format(i[0].strip(),i[1].strip(),i[2].strip())
    print(cmd,len(cmd))
    l.append(cmd)# general stucture
    #l.append("/usr/bin/ksh {0} {2}{1}".format(i[0].strip(),i[1].strip(),i[2].strip()))  # / already command csv lo mentioned.
    #l.append("{0} {2} {1}".format(i[0].strip(),i[1].strip(),i[2].strip())) # /usr/bin/ksh not in ctm
print()
a=d[['WRAPER_SCRIPT','PARAM','FOLDER_NAME','INFA_WORKFLOW']]
for i in a.values.tolist():
    if "NA_" in i:
        continue
    #cmd="/usr/bin/ksh {0} {1} {2} {3}".format(i[0].strip(),i[2].strip(),i[3].strip(),i[1].strip())
    cmd="{0} {1} {2} {3}".format(i[0].strip(),i[2].strip(),i[3].strip(),i[1].strip())
    print(cmd,len(cmd))
    l.append(cmd)
print()    
data=pd.read_excel(output,sheet_name='JOB')[['JOBNAME','PARENT_FOLDER','CMDLINE','NODEID','RUN_AS']].fillna("N/A")

mis=[]
for j in list(data.CMDLINE):
    
    if j not in l:
        
        print(j,len(j))
        id=data.index[data['CMDLINE'] == j.strip()].tolist()[0]
        mis.append([list(data.PARENT_FOLDER)[id],list(data.JOBNAME)[id],j])

keypoint=['PARENT_FOLDER','JOBNAME','CMDLINE']
import csv
with open("MISS_CMDLINE_JOBS.csv", "w", newline='') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(keypoint) # write the header
    # write the actual content line by line
    for l in mis:
        writer.writerow(l) 

print('success_COMMAND')
# Out:
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/WGS_HIST_BTEQ_LZ_LOAD_LOG_INS_LOAD.lst 114
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/WGS_CLM_BTEQ_HIST_WRAPPER.lst 105
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_LZ_HIST_TBL_DELETION_INTRVL.lst 120
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_LZ_HIST_CTRL_TBL_Load.lst 114
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_HIST_LZ_AUDT_STAT_LOAD.lst 115
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_HIST_LZ_AUDT_BLNC_STAT_LOAD.lst 120
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_HIST_LZ_AUDT_BAL_RCD_CNT_VRNC.lst 122
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_LZ_HIST_TBL_PURGE_LOAD.lst 115
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_WGS_CLM_HIST_LZ_LOAD_LOG_END_DTM_LOAD.lst 122
#
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_WGS_CLAIMS wf_CLM_WGS_LZ_INITIALIZE_WLM $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 130
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCDTLP_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 135
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCNATP_EA1_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 139
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCCLMP_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 135
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCND00_INCR_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 135
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCNATP_EA2_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 139
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCNATP_E00_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 139
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCNATP_EA3_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 139
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCNEA5_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 135
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCHSPP_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 135
# $PMDIR/ca_scripts/startwflow_ascii.sh ENT_EDLR2_PPM_CLAIMS wf_CLM_WGS_LZ_WGS_GNCNATP_C01_HIST_LD $PMDIR/InfaParm/WGS_CLAIMS_SRC_LZ_HIST.prm 139
#
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_HIST_WRAPPER.lst 105
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_CLM_WGS_HIST_LZ_LOAD_LOG_INS_LOAD.lst 118
# /usr/bin/ksh $PMDIR/ca_scripts/startshell.sh $CODE/edlr2_ppm_claims/scripts/BTEQ_WGS_CLM__HIST_LZ_LOAD_LOG_END_DTM_LOAD.lst 123
# success_COMMAND
